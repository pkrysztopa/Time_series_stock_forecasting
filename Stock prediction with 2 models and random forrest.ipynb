# %%
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
import numpy as np
from tensorflow import keras

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline

from pandas_datareader.data import DataReader
import yfinance as yf

from datetime import datetime

test_end = datetime.now()
train_end = datetime(2022, 11, test_end.day)
start = datetime(2022, 4, train_end.day)

Nasdaq = yf.download('^IXIC', start, train_end)

Nasdaq_test = yf.download('^IXIC', train_end, test_end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## Load previous models and make predictions

# %% [markdown]
# ### Previously two models where made, one using LSTM neural network, and second using RNN and lag feature. Two models make diffrent outputs and it seems that they have diffrent pros and cons. The next model will combine outputs from this two models.

# %%
model_lstm = keras.models.load_model('model_lstm')

# %%
model_rnn = keras.models.load_model('model_lag')

# %%
from Stock_prediction_with_lags import make_lags, make_steps, scaler
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18748\2041552602.py in <module>
# ----> 1 from Stock_prediction_with_lags import make_lags, make_steps, scaler
#
# ModuleNotFoundError: No module named 'Stock_prediction_with_lags'

# %%
X = pd.concat([make_lags(Nasdaq,5),Nasdaq],axis=1).dropna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18748\2715871407.py in <module>
# ----> 1 X = pd.concat([make_lags(Nasdaq,5),Nasdaq],axis=1).dropna()
#
# NameError: name 'make_lags' is not defined
